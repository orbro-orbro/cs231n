# %% [markdown]
# **生成式 AI 使用说明**：在本课程作业中，使用生成式 AI 需要遵守与协作讨论相同的政策。和其他合作者一样，每位学生都必须独立写出自己的解答，不能直接依赖交互输出完成提交内容，并且提交时应说明协作的性质。使用生成式 AI 工具实质性地完成作业中的部分内容，不符合本课程作业精神，也会违反 [Honor Code](https://communitystandards.stanford.edu/policies-and-guidance/honor-code)。

# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'

assert FOLDERNAME is not None, "[!] Enter the foldername."
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 收集提交文件——打包 ZIP 并生成 PDF
#
# 完成其他所有 notebook 后，请运行一次本 notebook：`knn.ipynb`、`softmax.ipynb`、`two_layer_net.ipynb`、`features.ipynb` 和 `FullyConnectedNets.ipynb`。
#
# 它会执行以下操作：
#
# * 将你的代码（`.py` 和 `.ipynb`）打包为名为 `a1_code_submission.zip` 的 ZIP 文件。
# * 将所有 notebook 转换并合并为名为 `a1_inline_submission.pdf` 的 PDF 文件。
#
# 如果这一步提交文件生成成功，你应该会看到以下提示：
#
# `### Done! Please submit a1_code_submission.zip and a1_inline_submission.pdf to Gradescope. ###`
#
# 请务必先把 ZIP 和 PDF 文件下载到本地计算机，然后再提交到 Gradescope。恭喜你完成本次作业！

# %%
# %cd drive/My\ Drive
# %cd $FOLDERNAME
# !sudo apt --fix-broken install -y
# !sudo apt-get install -y texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc
# !which xelatex
# !pip install PyPDF2
# !bash collectSubmission.sh
