# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = None

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %% [markdown]
# # 收集提交文件——压缩代码并生成 PDF
#
# <font color="red">**注意：**执行此步骤前，请务必运行所有 Notebook 中的全部单元格。对于缺失的单元格输出，我们不会重新评分。</font>
#
# 完成其他所有 Notebook 后，运行本 Notebook。
#
# 它将：
#
# * 把你的代码（`.py` 和 `.ipynb`）打包成名为 `a3_code_submission.zip` 的压缩文件。
# * 将所有 Notebook 转换为一个名为 `a3_inline_submission.pdf` 的 PDF 文件。
#
# 如果此步骤成功，你应该会看到以下消息：
#
# `### 完成！请将 a3_code_submission.zip 和 a3_inline_submission.pdf 提交到 Gradescope。###`
#
# 请务必将 zip 和 PDF 文件下载到本地计算机，然后提交至 Gradescope。恭喜你顺利完成本次作业！

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !sudo apt-get update
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh
