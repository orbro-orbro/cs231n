# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment2/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# %% [markdown]
# # 收集提交文件——打包 ZIP 并生成 PDF
#
# 完成所有其他笔记本后，运行此笔记本：`BatchNormalization.ipynb`、`Dropout.ipynb`、`ConvolutionalNetworks.ipynb`、`PyTorch.ipynb` 和 `RNN_Captioning_pytorch.ipynb`。
#
# 它将：
#
# * 将你的代码（`.py` 和 `.ipynb`）打包成名为 `a2.zip` 的 ZIP 文件。
# * 将所有笔记本转换为一个名为 `assignment.pdf` 的 PDF 文件。
#
# 如果此步骤成功完成，你应该会看到以下提示信息：
#
# `### Done! Please submit a2.zip and the pdfs to Gradescope. ###`
#
# 请务必将 ZIP 和 PDF 文件下载到本地计算机，然后提交到 Gradescope。恭喜你顺利完成本次作业！

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh
